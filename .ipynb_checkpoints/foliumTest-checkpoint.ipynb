# %%
import folium

# %%
m = folium.Map(location=(45.5236, -122.6750))
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_97d5d081bad4311469acb2d4d567d26d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_97d5d081bad4311469acb2d4d567d26d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_97d5d081bad4311469acb2d4d567d26d = L.map(
#                 &quot;map_97d5d081bad4311469acb2d4d567d26d&quot;,
#                 {
#                     center: [45.5236, -122.675],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_04ab8e39b0d8e4828695353ec00897ea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_04ab8e39b0d8e4828695353ec00897ea.addTo(map_97d5d081bad4311469acb2d4d567d26d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from ortools.constraint_solver import pywrapcp, routing_enums_pb2
import folium

# Example data
def create_data_model():
    data = {}
    data['distance_matrix'] = [
        [0, 2, 9, 10],
        [1, 0, 6, 4],
        [15, 7, 0, 8],
        [6, 3, 12, 0],
    ]
    data['num_vehicles'] = 1
    data['depot'] = 0
    return data

def main():
    data = create_data_model()
    
    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']), data['num_vehicles'], data['depot'])
    
    routing = pywrapcp.RoutingModel(manager)
    
    def distance_callback(from_index, to_index):
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return data['distance_matrix'][from_node][to_node]
    
    transit_callback_index = routing.RegisterTransitCallback(distance_callback)
    
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)
    
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)
    
    solution = routing.SolveWithParameters(search_parameters)
    
    if solution:
        route = []
        index = routing.Start(0)
        while not routing.IsEnd(index):
            route.append(manager.IndexToNode(index))
            index = solution.Value(routing.NextVar(index))
        route.append(manager.IndexToNode(index))
        return route

route = main()
print(route)

# Coordinates for each location (latitude, longitude)
coordinates = [
    (37.7749, -122.4194),  # San Francisco
    (34.0522, -118.2437),  # Los Angeles
    (36.1699, -115.1398),  # Las Vegas
    (40.7128, -74.0060)    # New York
]

# Create a map centered at the first location
m = folium.Map(location=coordinates[0], zoom_start=6)

# Add markers for each location
for i, coord in enumerate(coordinates):
    folium.Marker(coord, popup=f"Location {i}").add_to(m)

# Add lines to represent the route
route_coords = [coordinates[i] for i in route]
folium.PolyLine(route_coords, color="blue", weight=2.5, opacity=1).add_to(m)

# Save the map to an HTML file
m.save("route_map.html")
# Out:
# [0, 2, 3, 1, 0]

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b8f39b012a55b45276f9ecfde16ed8c7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b8f39b012a55b45276f9ecfde16ed8c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b8f39b012a55b45276f9ecfde16ed8c7 = L.map(
#                 &quot;map_b8f39b012a55b45276f9ecfde16ed8c7&quot;,
#                 {
#                     center: [37.7749, -122.4194],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a43bf0055cea919e31e535b259ac3d3d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a43bf0055cea919e31e535b259ac3d3d.addTo(map_b8f39b012a55b45276f9ecfde16ed8c7);
#
#
#             var marker_a5329ec8ce9eafb204e61856aeb9f83d = L.marker(
#                 [37.7749, -122.4194],
#                 {}
#             ).addTo(map_b8f39b012a55b45276f9ecfde16ed8c7);
#
#
#         var popup_2be1e597e09b8912361dc4f08198c7cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7e88d171a28c42a2861c0e26c4eca70f = $(`&lt;div id=&quot;html_7e88d171a28c42a2861c0e26c4eca70f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Location 0&lt;/div&gt;`)[0];
#                 popup_2be1e597e09b8912361dc4f08198c7cb.setContent(html_7e88d171a28c42a2861c0e26c4eca70f);
#
#
#
#         marker_a5329ec8ce9eafb204e61856aeb9f83d.bindPopup(popup_2be1e597e09b8912361dc4f08198c7cb)
#         ;
#
#
#
#
#             var marker_e21de96de7fe433ad8590fb5b9ae2327 = L.marker(
#                 [34.0522, -118.2437],
#                 {}
#             ).addTo(map_b8f39b012a55b45276f9ecfde16ed8c7);
#
#
#         var popup_bf657c52e5729dc91076618caed87a77 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3a15fec595a5db13ff7cb508c0af0e37 = $(`&lt;div id=&quot;html_3a15fec595a5db13ff7cb508c0af0e37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Location 1&lt;/div&gt;`)[0];
#                 popup_bf657c52e5729dc91076618caed87a77.setContent(html_3a15fec595a5db13ff7cb508c0af0e37);
#
#
#
#         marker_e21de96de7fe433ad8590fb5b9ae2327.bindPopup(popup_bf657c52e5729dc91076618caed87a77)
#         ;
#
#
#
#
#             var marker_a8c6d1cce708d80834c0d44c1c902bc2 = L.marker(
#                 [36.1699, -115.1398],
#                 {}
#             ).addTo(map_b8f39b012a55b45276f9ecfde16ed8c7);
#
#
#         var popup_83593f206aaa02b887f99813fe845d84 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_285887005f5ce4f779d6c1a6ea0a8384 = $(`&lt;div id=&quot;html_285887005f5ce4f779d6c1a6ea0a8384&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Location 2&lt;/div&gt;`)[0];
#                 popup_83593f206aaa02b887f99813fe845d84.setContent(html_285887005f5ce4f779d6c1a6ea0a8384);
#
#
#
#         marker_a8c6d1cce708d80834c0d44c1c902bc2.bindPopup(popup_83593f206aaa02b887f99813fe845d84)
#         ;
#
#
#
#
#             var marker_7d5c002e3f30511e4595fe83e1eae19f = L.marker(
#                 [40.7128, -74.006],
#                 {}
#             ).addTo(map_b8f39b012a55b45276f9ecfde16ed8c7);
#
#
#         var popup_928b8883d5503f7fd7359f9144499862 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_83622cea31d8a26d8e6440273d77cb81 = $(`&lt;div id=&quot;html_83622cea31d8a26d8e6440273d77cb81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Location 3&lt;/div&gt;`)[0];
#                 popup_928b8883d5503f7fd7359f9144499862.setContent(html_83622cea31d8a26d8e6440273d77cb81);
#
#
#
#         marker_7d5c002e3f30511e4595fe83e1eae19f.bindPopup(popup_928b8883d5503f7fd7359f9144499862)
#         ;
#
#
#
#
#             var poly_line_e634f42eaf832f895493db43211d0e41 = L.polyline(
#                 [[37.7749, -122.4194], [36.1699, -115.1398], [40.7128, -74.006], [34.0522, -118.2437], [37.7749, -122.4194]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_b8f39b012a55b45276f9ecfde16ed8c7);
#
#
#             tile_layer_a43bf0055cea919e31e535b259ac3d3d.addTo(map_b8f39b012a55b45276f9ecfde16ed8c7);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;
